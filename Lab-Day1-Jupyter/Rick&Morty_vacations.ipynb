# %% [markdown]
# # <font color=green> Rick and Morty on vacations </font>

# %% [markdown]
# ***

# %% [markdown]
# ## Index
# * [1. Introduction](#introduction)
# * [2. Video](#video)
# * [3. Preferences](#preferences)
# * [4. Functions](#functions)

# %% [markdown]
# ### 1. Introduction <a class="anchor" id="introduction"></a>
# **After their exhausting adventures, Rick and Morty deserve a break. In this notebook, you would learn more about how these guys like to relax and disconnect from the ''reality''.**

# %% [markdown]
# ![enter-rick-morty-contest-02.jpg](attachment:enter-rick-morty-contest-02.jpg)

# %% [markdown]
# ### 2. Video <a class="anchor" id="video"></a>
# **Do you want to see how? Check this video!**

# %% [markdown]
# [Rick and Morty relaxing](https://youtu.be/GVm9bNTEWyU)

# %% [markdown]
# ![Rick_and_Morty_relaxing.png](attachment:Rick_and_Morty_relaxing.png)

# %% [markdown]
# ### 3. Preferences <a class="anchor" id="preferences"></a>
# #### Which are Rick and Morty holidays preferences?

# %% [markdown]
# - Relaxing on exotic Spas
# - Creating some space-chaos
# - Making Jerry feel like a loser

# %% [markdown]
# ### 4. Functions <a class="anchor" id="functions"></a>

# %%
username = input('Enter your name:')
def username():    
    return username
# Out:
# Enter your name:morty

# %%
holidays = input('Enter your holidays preference:')
def preference():
    return holidays
# Out:
# Enter your holidays preference:jessica
